# %%
import pandas as pd

# %%
# Leggi un CSV locale
df = pd.read_csv(r"C:\Users\SandroCantasanoMarti\Desktop\bq-results-20250918-183838-1758220735590.csv")

df.head()
# Out:
#    event_date   event_timestamp event_name  user_pseudo_id  \
# 0    20201101  1604188804579566  page_view    8.202397e+07
# 1    20201101  1604188806427147  page_view    7.754124e+06
# 2    20201101  1604188827483279  page_view    5.021426e+07
# 3    20201101  1604188843867564  page_view    8.202397e+07
# 4    20201101  1604188854567876  page_view    7.659669e+06
#
#                                        page_location  \
# 0           https://shop.googlemerchandisestore.com/
# 1  https://shop.googlemerchandisestore.com/Google...
# 2  https://shop.googlemerchandisestore.com/Google...
# 3  https://shop.googlemerchandisestore.com/Google...
# 4  https://shop.googlemerchandisestore.com/Google...
#
#                                           page_title  ga_session_id  \
# 0                                               Home     1090192382
# 1        Bags | Lifestyle | Google Merchandise Store     3291659989
# 2                                   Page Unavailable     9011333152
# ...

# %%
df
# Out:
#     event_date   event_timestamp event_name  user_pseudo_id  \
# 0     20201101  1604188804579566  page_view    8.202397e+07
# 1     20201101  1604188806427147  page_view    7.754124e+06
# 2     20201101  1604188827483279  page_view    5.021426e+07
# 3     20201101  1604188843867564  page_view    8.202397e+07
# 4     20201101  1604188854567876  page_view    7.659669e+06
# ..         ...               ...        ...             ...
# 95    20201101  1604190236172895  page_view    2.619033e+07
# 96    20201101  1604190247258591  page_view    3.663870e+07
# 97    20201101  1604190272432219  page_view    3.681327e+07
# 98    20201101  1604190289238984  page_view    4.514841e+07
# 99    20201101  1604190294635191  page_view    4.514841e+07
#
#                                         page_location  \
# 0            https://shop.googlemerchandisestore.com/
# 1   https://shop.googlemerchandisestore.com/Google...
# 2   https://shop.googlemerchandisestore.com/Google...
# ...
